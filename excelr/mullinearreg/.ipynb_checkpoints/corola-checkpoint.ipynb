# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
pd.set_option("display.max_rows",10)
pd.set_option("display.max_columns", 1440)

# %%
df = pd.read_csv("ToyotaCorolla.csv",encoding="ISO-8859-1")
df
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color   Color  \
# ...

# %%
y = df.iloc[:,2:3]
y
x = df[["Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]
x
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0            23  46986   90  2000      3      5            210    1165
# 1            23  72937   90  2000      3      5            210    1165
# 2            24  41711   90  2000      3      5            210    1165
# 3            26  48000   90  2000      3      5            210    1165
# 4            30  38500   90  2000      3      5            210    1170
# ...         ...    ...  ...   ...    ...    ...            ...     ...
# 1431         69  20544   86  1300      3      5             69    1025
# 1432         72  19000   86  1300      3      5             69    1015
# 1433         71  17016   86  1300      3      5             69    1015
# 1434         70  16916   86  1300      3      5             69    1015
# 1435         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 8 columns]

# %%
new_x = pd.get_dummies(x)
new_x
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0            23  46986   90  2000      3      5            210    1165
# 1            23  72937   90  2000      3      5            210    1165
# 2            24  41711   90  2000      3      5            210    1165
# 3            26  48000   90  2000      3      5            210    1165
# 4            30  38500   90  2000      3      5            210    1170
# ...         ...    ...  ...   ...    ...    ...            ...     ...
# 1431         69  20544   86  1300      3      5             69    1025
# 1432         72  19000   86  1300      3      5             69    1015
# 1433         71  17016   86  1300      3      5             69    1015
# 1434         70  16916   86  1300      3      5             69    1015
# 1435         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 8 columns]

# %%
sc = StandardScaler()
new_x1 = sc.fit_transform(new_x)
# new_x1

# %%
new_x1.shape
# Out:
# (1436, 8)

# %%
x_train,x_test,y_train,y_test = train_test_split(new_x1,y,test_size=0.2,random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
comp = pd.DataFrame({"pred":np.array(y_pred).reshape(-1),"actuals":np.array(y_test).reshape(-1)})

# %%
comp
# Out:
#              pred  actuals
# 0    11334.877221    10800
# 1     8930.649456     9950
# 2     9548.864621     7500
# 3     8965.065760     9250
# 4    10038.782357     9750
# ..            ...      ...
# 283  19042.142710    21950
# 284   8132.455959     8450
# 285  13588.762823    12850
# 286  10702.235018     6950
# 287  10790.746173     8900
#
# [288 rows x 2 columns]

# %%
r2_score(y_true=y_test,y_pred=y_pred)
# Out:
# 0.8538352805672251

# %% [markdown]
# Lets check r2_score for categorical variables doors and gears

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x.dtypes
# Out:
# Age_08_04        int64
# KM               int64
# HP               int64
# cc               int64
# Doors            int64
# Gears            int64
# Quarterly_Tax    int64
# Weight           int64
# dtype: object

# %%
x2 = x

# %%
# x2 = x[["Doors","Gears"]].astype("category")
categorical_columns = ["Doors","Gears"]

for cols in categorical_columns:
    x2[cols] = x2[cols].astype("category")
# Out:
# /tmp/ipykernel_23279/763051022.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x2[cols] = x2[cols].astype("category")

# %%
x2.dtypes
# Out:
# Age_08_04           int64
# KM                  int64
# HP                  int64
# cc                  int64
# Doors            category
# Gears            category
# Quarterly_Tax       int64
# Weight              int64
# dtype: object

# %%
x2 = pd.get_dummies(x2)

# %%
stndScaler = StandardScaler()
stndScaler.fit_transform(x2)
# Out:
# array([[-1.77196633, -0.57469494, -0.76804185, ..., -0.02639818,
#          0.18191626, -0.1756947 ],
#        [-1.77196633,  0.11745379, -0.76804185, ..., -0.02639818,
#          0.18191626, -0.1756947 ],
#        [-1.71818412, -0.71538641, -0.76804185, ..., -0.02639818,
#          0.18191626, -0.1756947 ],
#        ...,
#        [ 0.80957948, -1.37403589, -1.03513832, ..., -0.02639818,
#          0.18191626, -0.1756947 ],
#        [ 0.75579727, -1.37670303, -1.03513832, ..., -0.02639818,
#          0.18191626, -0.1756947 ],
#        [ 1.0784905 , -1.82784925,  0.5674405 , ..., -0.02639818,
#          0.18191626, -0.1756947 ]])

# %%
p,q,r,s = train_test_split(x2,y,test_size=0.2,random_state=42)

# %%
linreg  = LinearRegression()
linreg.fit(p,r)
# Out:
# LinearRegression()

# %%
new_pred = linreg.predict(q)

# %%
check_comp = pd.DataFrame({"pred":np.array(new_pred).reshape(-1),"actual":np.array(s).reshape(-1)})

# %%
check_comp
# Out:
#              pred  actual
# 0    11310.002620   10800
# 1     8912.362902    9950
# 2     9738.123559    7500
# 3     8947.910020    9250
# 4    10034.756140    9750
# ..            ...     ...
# 283  19042.759101   21950
# 284   8107.116897    8450
# 285  13573.050103   12850
# 286  10719.091900    6950
# 287  10774.928234    8900
#
# [288 rows x 2 columns]

# %%
r2_score(y_true=s,y_pred=new_pred)
# Out:
# 0.8535994152063605
