# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("wc-at.csv")

# %%
df.skew()
# Out:
# Waist    0.134056
# AT       0.584869
# dtype: float64

# %%
sns.histplot(df["Waist"],bins = 30, kde = True, color = "lightgreen", edgecolor = "red")
# Out:
# <Axes: xlabel='Waist', ylabel='Count'>
